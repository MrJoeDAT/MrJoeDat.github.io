# %% [markdown]
# # WEB SCRAPPING
#
# ### PULLING DATA FROM WIKIPEDIA
# #### LIST OF COMPANIES IN NIGERIA

# %% [markdown]
# https://en.wikipedia.org/wiki/List_of_companies_of_Nigeria

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_companies_of_Nigeria'
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html')

# %%
cmp = soup.find_all('th')[:6]
cmp
# Out:
# [<th>Name
#  </th>,
#  <th>Industry
#  </th>,
#  <th>Sector
#  </th>,
#  <th>Headquarters
#  </th>,
#  <th>Founded
#  </th>,
#  <th class="unsortable">Notes
#  </th>]

# %%
cmp = [title.text.strip() for title in cmp]
print(cmp)
# Out:
# ['Name', 'Industry', 'Sector', 'Headquarters', 'Founded', 'Notes']

# %%
df = pd.DataFrame(columns = cmp)
df
# Out:
# Empty DataFrame
# Columns: [Name, Industry, Sector, Headquarters, Founded, Notes]
# Index: []

# %%
cln = soup.find_all('tr')

# %%
for row in cln[2:34]:
    row = row.find_all('td')
    eachRow = [data.text.strip() for data in row]
    
    lth = len(df)
    df.loc[lth] = eachRow

# %%
df.to_csv(r'C:\Users\Mhizta Joe\Desktop\MrJoe\list.csv')
df
# Out:
#                                               Name           Industry  \
# 0                                      Access Bank         Financials
# 1                                 Aero Contractors  Consumer services
# 2                                         Arik Air  Consumer services
# 3                           Cassava Republic Press  Consumer services
# 4                          Central Bank of Nigeria         Financials
# 5                              Chanchangi Airlines  Consumer services
# 6                            C&I Leasing Group plc        Industrials
# 7                           Chocolate City Records  Consumer services
# 8                                         Dana Air  Consumer services
# 9                                   Dangote Cement        Industrials
# 10                                   Dangote Group      Conglomerates
# 11                                    Diamond Bank         Financials
# ...

# %% [markdown]
# #

# %% [markdown]
# # PULLING DATA FROM YAHOO FINANCE WITH YFINANCE
#
# ## APPLE INC. INCOME STATEMENT

# %% [markdown]
# https://finance.yahoo.com/quote/AAPL/financials?p=AAPL

# %%
# !pip install yfinance
import yfinance as yf
import pandas as pd

# %%
from IPython.core.display import clear_output
clear_output()

# %%
apl = yf.Ticker('AAPL')
apl.get_financials()
# Out:
#                                                         2022-09-30  \
# TaxEffectOfUnusualItems                                        0.0
# TaxRateForCalcs                                           0.162045
# NormalizedEBITDA                                    130541000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...   99803000000.0
# ReconciledDepreciation                               11104000000.0
# ReconciledCostOfRevenue                             223546000000.0
# EBIT                                                119437000000.0
# NetInterestIncome                                     -106000000.0
# InterestExpense                                       2931000000.0
# InterestIncome                                        2825000000.0
# NormalizedIncome                                     99803000000.0
# NetIncomeFromContinuingAndDiscontinuedOperation      99803000000.0
# TotalExpenses                                       274891000000.0
# ...
